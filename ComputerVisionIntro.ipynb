# %% [markdown]
# <a href="https://colab.research.google.com/github/git-siddhesh/Data_Science-dataprocessing-/blob/supervisedML/ComputerVisionIntro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
a=np.zeros((400,500))  # image of black color
b=np.full((400,500),255)   # image of white color

# %%
import cv2
import matplotlib.pyplot as plt
img=cv2.imread('dog.jpg',0)
img1=cv2.imread('dog.jpg',1)
# 1 means image in same color channel (rgb or bgr)
# 0 means black and white image 
# -1 means image transparency   not to remove transeparency

# to show image using matplotlib 
plt.imshow(img)
plt.imshow(img1)

# %%
img     #it will print a 3 d ndaray 
img.shape
# to show using other viewer
cv2.imshow('dog',img)
cv2.imshow('dog1',img1)

cv2.waitKey(0)

# %%
# to crop an image 
imgcrop=img[40:140,70:190]
plt.imshow(imgcrop)

# %%
b,g,r=cv2.split(img1)
plt.imshow(b)

# %%
plt.imshow(g)

# %%
# draw inside an image
  myimg=np.zeros((512,512))
  cv2.line(img,(0,0),(200,230),(0,0,255),3)
  cv2.rectangle(img,(50,50),(200,230),(0,0,255),3)
                  |    |        |         |     |  
             filename start & end-point color  width
      
      if width = -1 the the rectangle will fill up with color
